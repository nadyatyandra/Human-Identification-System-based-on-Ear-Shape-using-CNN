# %%
import numpy as np
import os
import PIL
import PIL.Image
import tensorflow as tf
import tensorflow_datasets as tfds
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
DATA_DIR = '../input/ear-dataset/EarVN1.0 dataset/Images'
IMG_HEIGHT = 224
IMG_WIDTH = 224
BATCH_SIZE = 32

# %%
train_val_ds = tf.keras.utils.image_dataset_from_directory(
  DATA_DIR,
  validation_split=0.15,
  label_mode='int',
  subset="training",
  seed=999,
  image_size=(IMG_HEIGHT, IMG_WIDTH),
  batch_size=BATCH_SIZE)
# Out:
# Found 28412 files belonging to 164 classes.
# Using 24151 files for training.

# %%
test_ds = tf.keras.utils.image_dataset_from_directory(
  DATA_DIR,
  validation_split=0.15,
  label_mode='int',
  subset="validation",
  seed=999,
  image_size=(IMG_HEIGHT, IMG_WIDTH),
  batch_size=BATCH_SIZE)
# Out:
# Found 28412 files belonging to 164 classes.
# Using 4261 files for validation.

# %%
train_val_batches = tf.data.experimental.cardinality(train_val_ds)
train_val_batches
# Out:
# <tf.Tensor: shape=(), dtype=int64, numpy=755>

# %%
TOTAL_TRAIN_VAL = len(train_val_ds)
print(TOTAL_TRAIN_VAL)
train_ds = train_val_ds.take(int(8 * train_val_batches / 10))
val_ds = train_val_ds.skip(int(8 * train_val_batches / 10))
print(len(train_ds))
print(len(val_ds))
# Out:
# 755
# 604
# 151

# %%
train_ds
# Out:
# <_TakeDataset element_spec=(TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
mc = ModelCheckpoint(
    filepath='./best_efficientnetv2s_model_epoch={epoch:02d}_acc={val_accuracy:0.4f}.h5',
    monitor="val_accuracy",
    verbose=1,
    save_best_only=True,
    save_weights_only=False,
    mode='max',
    save_freq='epoch'
)

# %%
from keras.models import load_model

model_path = '../input/best-efficientnetv2s-model-epoch09-acc0-8671/best_efficientnetv2s_model_epoch09_acc0.8671.h5'

model = load_model(model_path)

# %%
results = model.fit(train_ds, validation_data=val_ds, epochs=20, batch_size=32, callbacks=[mc])
# Out:
# Epoch 1/20
# 2024-01-19 16:23:22.167074: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape insequential/efficientnetv2-s/block1b_drop/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 604/604 [==============================] - ETA: 0s - loss: 0.1254 - accuracy: 0.9607
# Epoch 1: val_accuracy improved from -inf to 0.85797, saving model to ./best_efficientnetv2s_model_epoch=01_acc=0.8580.h5
# /opt/conda/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 604/604 [==============================] - 265s 316ms/step - loss: 0.1254 - accuracy: 0.9607 - val_loss: 0.6599 - val_accuracy: 0.8580
# Epoch 2/20
# 604/604 [==============================] - ETA: 0s - loss: 0.0974 - accuracy: 0.9684
# Epoch 2: val_accuracy did not improve from 0.85797
# 604/604 [==============================] - 188s 312ms/step - loss: 0.0974 - accuracy: 0.9684 - val_loss: 0.7164 - val_accuracy: 0.8499
# Epoch 3/20
# 604/604 [==============================] - ETA: 0s - loss: 0.1110 - accuracy: 0.9653
# Epoch 3: val_accuracy improved from 0.85797 to 0.85880, saving model to ./best_efficientnetv2s_model_epoch=03_acc=0.8588.h5
# 604/604 [==============================] - 188s 311ms/step - loss: 0.1110 - accuracy: 0.9653 - val_loss: 0.6753 - val_accuracy: 0.8588
# Epoch 4/20
# 604/604 [==============================] - ETA: 0s - loss: 0.1128 - accuracy: 0.9640
# Epoch 4: val_accuracy improved from 0.85880 to 0.88348, saving model to ./best_efficientnetv2s_model_epoch=04_acc=0.8835.h5
# 604/604 [==============================] - 187s 309ms/step - loss: 0.1128 - accuracy: 0.9640 - val_loss: 0.5643 - val_accuracy: 0.8835
# Epoch 5/20
# 604/604 [==============================] - ETA: 0s - loss: 0.0906 - accuracy: 0.9707
# Epoch 5: val_accuracy did not improve from 0.88348
# 604/604 [==============================] - 186s 307ms/step - loss: 0.0906 - accuracy: 0.9707 - val_loss: 0.6013 - val_accuracy: 0.8744
# Epoch 6/20
# 604/604 [==============================] - ETA: 0s - loss: 0.0903 - accuracy: 0.9718
# Epoch 6: val_accuracy did not improve from 0.88348
# 604/604 [==============================] - 187s 310ms/step - loss: 0.0903 - accuracy: 0.9718 - val_loss: 0.5978 - val_accuracy: 0.8785
# Epoch 7/20
# 604/604 [==============================] - ETA: 0s - loss: 0.0815 - accuracy: 0.9754
# Epoch 7: val_accuracy did not improve from 0.88348
# 604/604 [==============================] - 187s 309ms/step - loss: 0.0815 - accuracy: 0.9754 - val_loss: 0.5990 - val_accuracy: 0.8785
# Epoch 8/20
# 604/604 [==============================] - ETA: 0s - loss: 0.0806 - accuracy: 0.9748
# Epoch 8: val_accuracy did not improve from 0.88348
# 604/604 [==============================] - 186s 308ms/step - loss: 0.0806 - accuracy: 0.9748 - val_loss: 0.6347 - val_accuracy: 0.8768
# Epoch 9/20
# 604/604 [==============================] - ETA: 0s - loss: 0.0688 - accuracy: 0.9786
# Epoch 9: val_accuracy did not improve from 0.88348
# 604/604 [==============================] - 187s 309ms/step - loss: 0.0688 - accuracy: 0.9786 - val_loss: 0.6696 - val_accuracy: 0.8777
# Epoch 10/20
# 604/604 [==============================] - ETA: 0s - loss: 0.0889 - accuracy: 0.9723
# Epoch 10: val_accuracy improved from 0.88348 to 0.88368, saving model to ./best_efficientnetv2s_model_epoch=10_acc=0.8837.h5
# 604/604 [==============================] - 188s 312ms/step - loss: 0.0889 - accuracy: 0.9723 - val_loss: 0.6180 - val_accuracy: 0.8837
# Epoch 11/20
# 604/604 [==============================] - ETA: 0s - loss: 0.0782 - accuracy: 0.9752
# Epoch 11: val_accuracy improved from 0.88368 to 0.89281, saving model to ./best_efficientnetv2s_model_epoch=11_acc=0.8928.h5
# 604/604 [==============================] - 188s 311ms/step - loss: 0.0782 - accuracy: 0.9752 - val_loss: 0.5552 - val_accuracy: 0.8928
# Epoch 12/20
# 604/604 [==============================] - ETA: 0s - loss: 0.0775 - accuracy: 0.9757
# Epoch 12: val_accuracy did not improve from 0.89281
# 604/604 [==============================] - 186s 307ms/step - loss: 0.0775 - accuracy: 0.9757 - val_loss: 0.6283 - val_accuracy: 0.8802
# Epoch 13/20
# 604/604 [==============================] - ETA: 0s - loss: 0.0605 - accuracy: 0.9818
# Epoch 13: val_accuracy did not improve from 0.89281
# 604/604 [==============================] - 186s 307ms/step - loss: 0.0605 - accuracy: 0.9818 - val_loss: 0.5905 - val_accuracy: 0.8895
# Epoch 14/20
# 604/604 [==============================] - ETA: 0s - loss: 0.0654 - accuracy: 0.9805
# Epoch 14: val_accuracy did not improve from 0.89281
# 604/604 [==============================] - 186s 307ms/step - loss: 0.0654 - accuracy: 0.9805 - val_loss: 0.6070 - val_accuracy: 0.8903
# Epoch 15/20
# 604/604 [==============================] - ETA: 0s - loss: 0.0659 - accuracy: 0.9799
# Epoch 15: val_accuracy improved from 0.89281 to 0.89363, saving model to ./best_efficientnetv2s_model_epoch=15_acc=0.8936.h5
# 604/604 [==============================] - 187s 309ms/step - loss: 0.0659 - accuracy: 0.9799 - val_loss: 0.5497 - val_accuracy: 0.8936
# Epoch 16/20
# 604/604 [==============================] - ETA: 0s - loss: 0.0644 - accuracy: 0.9810
# Epoch 16: val_accuracy did not improve from 0.89363
# 604/604 [==============================] - 186s 307ms/step - loss: 0.0644 - accuracy: 0.9810 - val_loss: 0.5873 - val_accuracy: 0.8905
# Epoch 17/20
# 604/604 [==============================] - ETA: 0s - loss: 0.0703 - accuracy: 0.9796
# Epoch 17: val_accuracy did not improve from 0.89363
# 604/604 [==============================] - 185s 307ms/step - loss: 0.0703 - accuracy: 0.9796 - val_loss: 0.5729 - val_accuracy: 0.8916
# Epoch 18/20
# 604/604 [==============================] - ETA: 0s - loss: 0.0544 - accuracy: 0.9828
# Epoch 18: val_accuracy did not improve from 0.89363
# 604/604 [==============================] - 188s 311ms/step - loss: 0.0544 - accuracy: 0.9828 - val_loss: 0.6355 - val_accuracy: 0.8849
# Epoch 19/20
# 604/604 [==============================] - ETA: 0s - loss: 0.0605 - accuracy: 0.9808
# Epoch 19: val_accuracy did not improve from 0.89363
# 604/604 [==============================] - 186s 308ms/step - loss: 0.0605 - accuracy: 0.9808 - val_loss: 0.6662 - val_accuracy: 0.8882
# Epoch 20/20
# 604/604 [==============================] - ETA: 0s - loss: 0.0577 - accuracy: 0.9819
# Epoch 20: val_accuracy did not improve from 0.89363
# 604/604 [==============================] - 186s 308ms/step - loss: 0.0577 - accuracy: 0.9819 - val_loss: 0.6352 - val_accuracy: 0.8899
