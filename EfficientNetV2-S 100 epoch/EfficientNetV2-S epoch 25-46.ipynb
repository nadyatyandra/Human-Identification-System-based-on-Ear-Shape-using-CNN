# %%
import numpy as np
import os
import PIL
import PIL.Image
import tensorflow as tf
import tensorflow_datasets as tfds
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
DATA_DIR = '../input/ear-dataset/EarVN1.0 dataset/Images'
IMG_HEIGHT = 224
IMG_WIDTH = 224
BATCH_SIZE = 32

# %%
train_val_ds = tf.keras.utils.image_dataset_from_directory(
  DATA_DIR,
  validation_split=0.15,
  label_mode='int',
  subset="training",
  seed=999,
  image_size=(IMG_HEIGHT, IMG_WIDTH),
  batch_size=BATCH_SIZE)
# Out:
# Found 28412 files belonging to 164 classes.
# Using 24151 files for training.

# %%
test_ds = tf.keras.utils.image_dataset_from_directory(
  DATA_DIR,
  validation_split=0.15,
  label_mode='int',
  subset="validation",
  seed=999,
  image_size=(IMG_HEIGHT, IMG_WIDTH),
  batch_size=BATCH_SIZE)
# Out:
# Found 28412 files belonging to 164 classes.
# Using 4261 files for validation.

# %%
train_val_batches = tf.data.experimental.cardinality(train_val_ds)
train_val_batches
# Out:
# <tf.Tensor: shape=(), dtype=int64, numpy=755>

# %%
TOTAL_TRAIN_VAL = len(train_val_ds)
print(TOTAL_TRAIN_VAL)
train_ds = train_val_ds.take(int(8 * train_val_batches / 10))
val_ds = train_val_ds.skip(int(8 * train_val_batches / 10))
print(len(train_ds))
print(len(val_ds))
# Out:
# 755
# 604
# 151

# %%
train_ds
# Out:
# <_TakeDataset element_spec=(TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
mc = ModelCheckpoint(
    filepath='./best_efficientnetv2s_model_epoch={epoch:02d}_acc={val_accuracy:0.4f}.h5',
    monitor="val_accuracy",
    verbose=1,
    save_best_only=True,
    save_weights_only=False,
    mode='max',
    save_freq='epoch'
)

# %%
from keras.models import load_model

model_path = '../input/best-efficientnetv2s-model-epoch24-acc0-8936/best_efficientnetv2s_model_epoch24_acc0.8936.h5'

model = load_model(model_path)

# %%
results = model.fit(train_ds, validation_data=val_ds, epochs=26, batch_size=32, callbacks=[mc])
# Out:
# Epoch 1/26
# 2024-01-20 04:47:26.848072: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape insequential/efficientnetv2-s/block1b_drop/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 604/604 [==============================] - ETA: 0s - loss: 0.0658 - accuracy: 0.9795
# Epoch 1: val_accuracy improved from -inf to 0.88265, saving model to ./best_efficientnetv2s_model_epoch=01_acc=0.8826.h5
# /opt/conda/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 604/604 [==============================] - 275s 320ms/step - loss: 0.0658 - accuracy: 0.9795 - val_loss: 0.6345 - val_accuracy: 0.8826
# Epoch 2/26
# 604/604 [==============================] - ETA: 0s - loss: 0.0668 - accuracy: 0.9794
# Epoch 2: val_accuracy improved from 0.88265 to 0.89052, saving model to ./best_efficientnetv2s_model_epoch=02_acc=0.8905.h5
# 604/604 [==============================] - 190s 314ms/step - loss: 0.0668 - accuracy: 0.9794 - val_loss: 0.5884 - val_accuracy: 0.8905
# Epoch 3/26
# 604/604 [==============================] - ETA: 0s - loss: 0.0546 - accuracy: 0.9840
# Epoch 3: val_accuracy improved from 0.89052 to 0.89177, saving model to ./best_efficientnetv2s_model_epoch=03_acc=0.8918.h5
# 604/604 [==============================] - 189s 313ms/step - loss: 0.0546 - accuracy: 0.9840 - val_loss: 0.5653 - val_accuracy: 0.8918
# Epoch 4/26
# 604/604 [==============================] - ETA: 0s - loss: 0.0491 - accuracy: 0.9852
# Epoch 4: val_accuracy improved from 0.89177 to 0.89674, saving model to ./best_efficientnetv2s_model_epoch=04_acc=0.8967.h5
# 604/604 [==============================] - 191s 316ms/step - loss: 0.0491 - accuracy: 0.9852 - val_loss: 0.5650 - val_accuracy: 0.8967
# Epoch 5/26
# 604/604 [==============================] - ETA: 0s - loss: 0.0608 - accuracy: 0.9816
# Epoch 5: val_accuracy did not improve from 0.89674
# 604/604 [==============================] - 189s 313ms/step - loss: 0.0608 - accuracy: 0.9816 - val_loss: 0.5976 - val_accuracy: 0.8899
# Epoch 6/26
# 604/604 [==============================] - ETA: 0s - loss: 0.0518 - accuracy: 0.9839
# Epoch 6: val_accuracy did not improve from 0.89674
# 604/604 [==============================] - 188s 311ms/step - loss: 0.0518 - accuracy: 0.9839 - val_loss: 0.5770 - val_accuracy: 0.8945
# Epoch 7/26
# 604/604 [==============================] - ETA: 0s - loss: 0.0658 - accuracy: 0.9800
# Epoch 7: val_accuracy did not improve from 0.89674
# 604/604 [==============================] - 189s 312ms/step - loss: 0.0658 - accuracy: 0.9800 - val_loss: 0.6055 - val_accuracy: 0.8895
# Epoch 8/26
# 604/604 [==============================] - ETA: 0s - loss: 0.0574 - accuracy: 0.9825
# Epoch 8: val_accuracy did not improve from 0.89674
# 604/604 [==============================] - 188s 311ms/step - loss: 0.0574 - accuracy: 0.9825 - val_loss: 0.5736 - val_accuracy: 0.8945
# Epoch 9/26
# 604/604 [==============================] - ETA: 0s - loss: 0.0468 - accuracy: 0.9858
# Epoch 9: val_accuracy did not improve from 0.89674
# 604/604 [==============================] - 189s 313ms/step - loss: 0.0468 - accuracy: 0.9858 - val_loss: 0.6070 - val_accuracy: 0.8957
# Epoch 10/26
# 604/604 [==============================] - ETA: 0s - loss: 0.0519 - accuracy: 0.9846
# Epoch 10: val_accuracy did not improve from 0.89674
# 604/604 [==============================] - 189s 313ms/step - loss: 0.0519 - accuracy: 0.9846 - val_loss: 0.5699 - val_accuracy: 0.8967
# Epoch 11/26
# 604/604 [==============================] - ETA: 0s - loss: 0.0524 - accuracy: 0.9832
# Epoch 11: val_accuracy improved from 0.89674 to 0.89944, saving model to ./best_efficientnetv2s_model_epoch=11_acc=0.8994.h5
# 604/604 [==============================] - 190s 315ms/step - loss: 0.0524 - accuracy: 0.9832 - val_loss: 0.5935 - val_accuracy: 0.8994
# Epoch 12/26
# 604/604 [==============================] - ETA: 0s - loss: 0.0485 - accuracy: 0.9852
# Epoch 12: val_accuracy improved from 0.89944 to 0.90442, saving model to ./best_efficientnetv2s_model_epoch=12_acc=0.9044.h5
# 604/604 [==============================] - 190s 314ms/step - loss: 0.0485 - accuracy: 0.9852 - val_loss: 0.5458 - val_accuracy: 0.9044
# Epoch 13/26
# 604/604 [==============================] - ETA: 0s - loss: 0.0370 - accuracy: 0.9888
# Epoch 13: val_accuracy did not improve from 0.90442
# 604/604 [==============================] - 200s 331ms/step - loss: 0.0370 - accuracy: 0.9888 - val_loss: 0.5934 - val_accuracy: 0.8953
# Epoch 14/26
# 604/604 [==============================] - ETA: 0s - loss: 0.0509 - accuracy: 0.9847
# Epoch 14: val_accuracy did not improve from 0.90442
# 604/604 [==============================] - 189s 313ms/step - loss: 0.0509 - accuracy: 0.9847 - val_loss: 0.5603 - val_accuracy: 0.9026
# Epoch 15/26
# 604/604 [==============================] - ETA: 0s - loss: 0.0442 - accuracy: 0.9855
# Epoch 15: val_accuracy did not improve from 0.90442
# 604/604 [==============================] - 189s 313ms/step - loss: 0.0442 - accuracy: 0.9855 - val_loss: 0.5952 - val_accuracy: 0.9019
# Epoch 16/26
# 604/604 [==============================] - ETA: 0s - loss: 0.0556 - accuracy: 0.9829
# Epoch 16: val_accuracy did not improve from 0.90442
# 604/604 [==============================] - 189s 313ms/step - loss: 0.0556 - accuracy: 0.9829 - val_loss: 0.5635 - val_accuracy: 0.8978
# Epoch 17/26
# 604/604 [==============================] - ETA: 0s - loss: 0.0420 - accuracy: 0.9874
# Epoch 17: val_accuracy did not improve from 0.90442
# 604/604 [==============================] - 190s 315ms/step - loss: 0.0420 - accuracy: 0.9874 - val_loss: 0.5664 - val_accuracy: 0.9032
# Epoch 18/26
# 604/604 [==============================] - ETA: 0s - loss: 0.0474 - accuracy: 0.9852
# Epoch 18: val_accuracy did not improve from 0.90442
# 604/604 [==============================] - 188s 310ms/step - loss: 0.0474 - accuracy: 0.9852 - val_loss: 0.5602 - val_accuracy: 0.9042
# Epoch 19/26
# 604/604 [==============================] - ETA: 0s - loss: 0.0408 - accuracy: 0.9891
# Epoch 19: val_accuracy improved from 0.90442 to 0.90504, saving model to ./best_efficientnetv2s_model_epoch=19_acc=0.9050.h5
# 604/604 [==============================] - 190s 314ms/step - loss: 0.0408 - accuracy: 0.9891 - val_loss: 0.5428 - val_accuracy: 0.9050
# Epoch 20/26
# 604/604 [==============================] - ETA: 0s - loss: 0.0416 - accuracy: 0.9871
# Epoch 20: val_accuracy did not improve from 0.90504
# 604/604 [==============================] - 189s 312ms/step - loss: 0.0416 - accuracy: 0.9871 - val_loss: 0.6695 - val_accuracy: 0.8858
# Epoch 21/26
# 604/604 [==============================] - ETA: 0s - loss: 0.0372 - accuracy: 0.9886
# Epoch 21: val_accuracy did not improve from 0.90504
# 604/604 [==============================] - 192s 318ms/step - loss: 0.0372 - accuracy: 0.9886 - val_loss: 0.5747 - val_accuracy: 0.9003
# Epoch 22/26
# 604/604 [==============================] - ETA: 0s - loss: 0.0386 - accuracy: 0.9887
# Epoch 22: val_accuracy improved from 0.90504 to 0.90877, saving model to ./best_efficientnetv2s_model_epoch=22_acc=0.9088.h5
# 604/604 [==============================] - 196s 325ms/step - loss: 0.0386 - accuracy: 0.9887 - val_loss: 0.5898 - val_accuracy: 0.9088
# Epoch 23/26
# 604/604 [==============================] - ETA: 0s - loss: 0.0402 - accuracy: 0.9880
# Epoch 23: val_accuracy did not improve from 0.90877
# 604/604 [==============================] - 188s 311ms/step - loss: 0.0402 - accuracy: 0.9880 - val_loss: 0.5659 - val_accuracy: 0.9069
# Epoch 24/26
# 604/604 [==============================] - ETA: 0s - loss: 0.0487 - accuracy: 0.9853
# Epoch 24: val_accuracy did not improve from 0.90877
# 604/604 [==============================] - 190s 314ms/step - loss: 0.0487 - accuracy: 0.9853 - val_loss: 0.5867 - val_accuracy: 0.8994
# Epoch 25/26
# 604/604 [==============================] - ETA: 0s - loss: 0.0336 - accuracy: 0.9897
# Epoch 25: val_accuracy did not improve from 0.90877
# 604/604 [==============================] - 189s 312ms/step - loss: 0.0336 - accuracy: 0.9897 - val_loss: 0.5561 - val_accuracy: 0.9040
# Epoch 26/26
# 604/604 [==============================] - ETA: 0s - loss: 0.0370 - accuracy: 0.9887
# Epoch 26: val_accuracy did not improve from 0.90877
# 604/604 [==============================] - 189s 313ms/step - loss: 0.0370 - accuracy: 0.9887 - val_loss: 0.6131 - val_accuracy: 0.8949
