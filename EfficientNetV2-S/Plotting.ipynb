# %%
from matplotlib import pyplot as plt

# %%
train_accuracy = [0.0751, 0.5246, 0.8157, 0.9064, 0.9380, # 1 - 5
                  0.9543, 0.9619, 0.9638, 0.9724, 0.9735, # 6 - 10
                  0.9763, 0.9765, 0.9760, 0.9775, 0.9774, # 11 - 15
                  0.9818, 0.9820, 0.9786, 0.9815, 0.9842, # 16 - 20
                  0.9855, 0.9831, 0.9847, 0.9835, 0.9883, # 21 - 25
                  0.9870, 0.9846, 0.9841, 0.9856, 0.9876, # 26 - 30
                  0.9893, 0.9873, 0.9893, 0.9876, 0.9886, # 31 - 35
                  0.9880, 0.9880, 0.9905, 0.9898, 0.9889, # 36 - 40
                  0.9889, 0.9903, 0.9926, 0.9919, 0.9886, # 41 - 45
                  0.9911, 0.9892, 0.9910, 0.9916, 0.9915  # 46 - 50
                 ]

# %%
val_accuracy = [0.3017, 0.7230, 0.8036, 0.8401, 0.8335, # 1 - 5
                0.8571, 0.8557, 0.8603, 0.8576, 0.8677, # 6 - 10
                0.8700, 0.8690, 0.8671, 0.8642, 0.8569, # 11 - 15
                0.8731, 0.8752, 0.8692, 0.8829, 0.8669, # 16 - 20
                0.8812, 0.8876, 0.8841, 0.8916, 0.8967, # 21 - 25
                0.8897, 0.8659, 0.8783, 0.8907, 0.8831, # 26 - 30
                0.8727, 0.8918, 0.8895, 0.8901, 0.8936, # 31 - 35
                0.8961, 0.9046, 0.8978, 0.9021, 0.8963, # 36 - 40
                0.8911, 0.8994, 0.8974, 0.8864, 0.8940, # 41 - 45
                0.9023, 0.9048, 0.9061, 0.8953, 0.9061  # 46 - 50
               ]

# %%
plt.plot(train_accuracy)
plt.plot(val_accuracy)
plt.title('EfficientNetV2-S Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
train_loss = [4.3141, 1.7847, 0.6407, 0.3089, 0.2003, # 1 - 5
              0.1454, 0.1254, 0.1159, 0.0907, 0.0836, # 6 - 10
              0.0828, 0.0817, 0.0780, 0.0738, 0.0724, # 11 - 15
              0.0622, 0.0579, 0.0671, 0.0605, 0.0558, # 16 - 20
              0.0488, 0.0572, 0.0492, 0.0549, 0.0409, # 21 - 25
              0.0440, 0.0538, 0.0512, 0.0470, 0.0413, # 26 - 30
              0.0355, 0.0430, 0.0343, 0.0435, 0.0401, # 31 - 35
              0.0381, 0.0399, 0.0318, 0.0340, 0.0344, # 36 - 40
              0.0362, 0.0352, 0.0270, 0.0290, 0.0358, # 41 - 45
              0.0278, 0.0358, 0.0297, 0.0281, 0.0253  # 46 - 50
             ]

# %%
val_loss = [2.7444, 1.0135, 0.7220, 0.6491, 0.6958, # 1 - 5
            0.6148, 0.6171, 0.5911, 0.6309, 0.6178, # 6 - 10
            0.5906, 0.6182, 0.5943, 0.5937, 0.6383, # 11 - 15
            0.5874, 0.5518, 0.5894, 0.5460, 0.6495, # 16 - 20
            0.5359, 0.5437, 0.5476, 0.5227, 0.4592, # 21 - 25
            0.5019, 0.6446, 0.5964, 0.5377, 0.5675, # 26 - 30
            0.6418, 0.5001, 0.5209, 0.4805, 0.4907, # 31 - 35
            0.5282, 0.4435, 0.4738, 0.5194, 0.5089, # 36 - 40
            0.5570, 0.5232, 0.5053, 0.5813, 0.5211, # 41 - 45
            0.5206, 0.4764, 0.4988, 0.5193, 0.4940  # 46 - 50
           ]

# %%
plt.plot(train_loss)
plt.plot(val_loss)
plt.title('EfficientNetV2-S Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
